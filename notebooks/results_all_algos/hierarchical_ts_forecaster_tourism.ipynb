# %%
import gpforecaster as gpf
import htsmodels as hts
import tsaugmentation as tsag
import matplotlib.pyplot as plt
import os
# Out:
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/json.py:45: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
dataset_name = 'tourism'
dataset = tsag.preprocessing.PreprocessDatasets(dataset_name)
groups = dataset.apply_preprocess()

# %%
# Store original results

for transf in ['jitter', 'time_warp', 'magnitude_warp', 'scaling']:
    algorithm = 'gpf'
    gpf_model = gpf.model.GPF(f'{dataset_name}_{algorithm}_{transf}_orig_s0', groups)
    model, like = gpf_model.train()
    mean, lower, upper = gpf_model.predict(model, like)
    res = gpf_model.metrics(mean)
    gpf_model.store_metrics(res)

    algorithm = 'mint'
    mint = hts.models.MinT(dataset=f'{dataset_name}_{algorithm}_{transf}_orig_s0', 
                           groups=groups, 
                           aggregate_key = '(State / Zone / Region) * Purpose')
    forecasts = mint.train()
    results = mint.results(forecasts)
    res = mint.metrics(results)
    mint.store_metrics(res)

    algorithm = 'deepar'
    deepar = hts.models.DeepAR(dataset=f'{dataset_name}_{algorithm}_{transf}_orig_s0', groups=groups)
    model = deepar.train()
    forecasts = deepar.predict(model)
    results = deepar.results(forecasts)
    res = deepar.metrics(results)
    deepar.store_metrics(res)
# Out:
# R[write to console]: ── Attaching packages ───────────────────────────────── fpp3 0.4.0 ──
#
# R[write to console]: ✔ tibble      3.1.5      ✔ tsibble     1.1.1
# ✔ dplyr       1.0.7      ✔ tsibbledata 0.3.0
# ✔ tidyr       1.1.4      ✔ feasts      0.2.2
# ✔ lubridate   1.7.10     ✔ fable       0.3.1
# ✔ ggplot2     3.3.5
#
# R[write to console]: ── Conflicts ────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()
#
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:02<00:00, 22.05it/s, epoch=1/100, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:02<00:00, 23.81it/s, epoch=2/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:02<00:00, 24.31it/s, epoch=3/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 24.56it/s, epoch=4/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 23.79it/s, epoch=5/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 24.10it/s, epoch=6/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:02<00:00, 23.30it/s, epoch=7/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 23.65it/s, epoch=8/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.57it/s, epoch=9/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.77it/s, epoch=10/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:02<00:00, 24.08it/s, epoch=11/100, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:02<00:00, 23.82it/s, epoch=12/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:02<00:00, 23.84it/s, epoch=13/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 24.00it/s, epoch=14/100, avg_epoch_loss=4.44]
# 100%|██████████| 50/50 [00:02<00:00, 23.64it/s, epoch=15/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 24.60it/s, epoch=16/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:02<00:00, 24.25it/s, epoch=17/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.99it/s, epoch=18/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.87it/s, epoch=19/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:02<00:00, 24.57it/s, epoch=20/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 24.23it/s, epoch=21/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 24.02it/s, epoch=22/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 23.82it/s, epoch=23/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:02<00:00, 23.52it/s, epoch=24/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:02<00:00,
py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:02<00:00, 20.49it/s, epoch=1/100, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:02<00:00, 22.12it/s, epoch=2/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.16it/s, epoch=3/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:02<00:00, 23.50it/s, epoch=4/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:02<00:00, 23.30it/s, epoch=5/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:02<00:00, 23.52it/s, epoch=6/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:02<00:00, 22.81it/s, epoch=7/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 22.67it/s, epoch=8/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:02<00:00, 22.97it/s, epoch=9/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.22it/s, epoch=10/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:02<00:00, 23.10it/s, epoch=11/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 22.78it/s, epoch=12/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.30it/s, epoch=13/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 23.42it/s, epoch=14/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:02<00:00, 23.19it/s, epoch=15/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 22.99it/s, epoch=16/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:02<00:00, 23.61it/s, epoch=17/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 22.94it/s, epoch=18/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 22.84it/s, epoch=19/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 23.15it/s, epoch=20/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:02<00:00, 22.98it/s, epoch=21/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 22.52it/s, epoch=22/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:02<00:00, 22.49it/s, epoch=23/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.38it/s, epoch=24/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.68it/s, epoch=25/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 22.71it/s, epoch=26/100, avg_epoch_loss=5.01]
# 100%|██████████| 50/50 [00:02<00:00, 24.25it/s, epoch=27/100, avg_epoch_loss=5.03]
# 100%|██████████| 50/50 [00:02<00:00, 24.71it/s, epoch=28/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:02<00:00, 23.59it/s, epoch=29/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:02<00:00, 22.56it/s, epoch=30/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:02<00:00, 23.66it/s, epoch=31/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:02<00:00, 22.22it/s, epoch=32/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 22.96it/s, epoch=33/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 22.30it/s, epoch=34/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:02<00:00, 22.85it/s, epoch=35/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:02<00:00, 22.76it/s, epoch=36/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:02<00:00, 23.33it/s, epoch=37/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.13it/s, epoch=38/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 22.74it/s, epoch=39/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 23.91it/s, epoch=40/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:02<00:00, 22.61it/s, epoch=41/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 24.23it/s, epoch=42/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.77it/s, epoch=43/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:02<00:00, 23.13it/s, epoch=44/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.65it/s, epoch=45/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 22.50it/s, epoch=46/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.50it/s, epoch=47/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 22.91it/s, epoch=48/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 22.74it/s, epoch=49/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.79it/s, epoch=50/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:02<00:00, 23.87it/s, epoch=51/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.63it/s, epoch=52/100, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:02<00:00, 22.39it/s, epoch=53/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.76it/s, epoch=54/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 23.18it/s, epoch=55/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 23.84it/s, epoch=56/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 23.39it/s, epoch=57/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 23.74it/s, epoch=58/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:02<00:00, 22.32it/s, epoch=59/100, avg_epoch_loss=4.98]
# 100%|██████████| 50/50 [00:02<00:00, 22.75it/s, epoch=60/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:02<00:00, 22.70it/s, epoch=61/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.01it/s, epoch=62/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:02<00:00, 22.85it/s, epoch=63/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 22.81it/s, epoch=64/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.49it/s, epoch=65/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.24it/s, epoch=66/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 22.83it/s, epoch=67/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.72it/s, epoch=68/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 23.27it/s, epoch=69/100, avg_epoch_loss=5.01]
# 100%|██████████| 50/50 [00:02<00:00, 22.33it/s, epoch=70/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:02<00:00, 22.09it/s, epoch=71/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:02<00:00, 23.03it/s, epoch=72/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:02<00:00, 23.20it/s, epoch=73/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 22.86it/s, epoch=74/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 23.76it/s, epoch=75/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 24.72it/s, epoch=76/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 23.24it/s, epoch=77/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 22.35it/s, epoch=78/100, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:02<00:00, 22.70it/s, epoch=79/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.34it/s, epoch=80/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 22.55it/s, epoch=81/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:02<00:00, 23.15it/s, epoch=82/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 24.27it/s, epoch=83/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 22.89it/s, epoch=84/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 22.33it/s, epoch=85/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:02<00:00, 23.24it/s, epoch=86/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.21it/s, epoch=87/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:02<00:00, 22.37it/s, epoch=88/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 23.14it/s, epoch=89/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:02<00:00, 22.38it/s, epoch=90/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 22.93it/s, epoch=91/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:02<00:00, 22.89it/s, epoch=92/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 22.58it/s, epoch=93/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 23.12it/s, epoch=94/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:02<00:00, 23.97it/s, epoch=95/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:02<00:00, 22.80it/s, epoch=96/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:02<00:00, 23.69it/s, epoch=97/100, avg_epoch_loss=4.22]
# 100%|██████████| 304/304 [00:01<00:00, 179.69it/s]

# %%
data = tsag.transformations.CreateTransformedVersions(dataset_name)
data.create_new_version_single_transf()

# %%
vis = tsag.visualization.Visualizer(dataset_name)

# %%
algorithm = 'gpf'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            gpf_model = gpf.model.GPF(f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups)
            model, like = gpf_model.train()
            mean, lower, upper = gpf_model.predict(model, like)
            res = gpf_model.metrics(mean)
            gpf_model.store_metrics(res)
# Out:
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-5-92322628bb94> in <module>
#       6             groups['train']['data'] = vis.y_new[i, j]
#       7             gpf_model = gpf.model.GPF(f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups)
# ----> 8             model, like = gpf_model.train()
#       9             mean, lower, upper = gpf_model.predict(model, like)
#      10             res = gpf_model.metrics(mean)
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpforecaster/model/gpf.py in train(self, n_iterations, lr)
#     127             optimizer.zero_grad()
#     128             output = model(*model.train_inputs)
# --> 129             loss = -mll(output, model.train_targets)
#     130             loss.backward()
#     131             print('Iter %d/%d - Loss: %.3f' % (i + 1, n_iterations, loss.item()))
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/module.py in __call__(self, *inputs, **kwargs)
#      28
#      29     def __call__(self, *inputs, **kwargs):
# ---> 30         outputs = self.forward(*inputs, **kwargs)
#      31         if isinstance(outputs, list):
#      32             return [_validate_module_outputs(output) for output in outputs]
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/mlls/sum_marginal_log_likelihood.py in forward(self, outputs, targets, *params)
#      31         """
#      32         if len(params) == 0:
# ---> 33             sum_mll = sum(mll(output, target) for mll, output, target in zip(self.mlls, outputs, targets))
#      34         else:
#      35             sum_mll = sum(
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/mlls/sum_marginal_log_likelihood.py in <genexpr>(.0)
#      31         """
#      32         if len(params) == 0:
# ---> 33             sum_mll = sum(mll(output, target) for mll, output, target in zip(self.mlls, outputs, targets))
#      34         else:
#      35             sum_mll = sum(
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/module.py in __call__(self, *inputs, **kwargs)
#      28
#      29     def __call__(self, *inputs, **kwargs):
# ---> 30         outputs = self.forward(*inputs, **kwargs)
#      31         if isinstance(outputs, list):
#      32             return [_validate_module_outputs(output) for output in outputs]
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py in forward(self, function_dist, target, *params)
#      60         # Get the log prob of the marginal distribution
#      61         output = self.likelihood(function_dist, *params)
# ---> 62         res = output.log_prob(target)
#      63         res = self._add_other_terms(res, params)
#      64
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/distributions/multivariate_normal.py in log_prob(self, value)
#     166
#     167         # Get log determininant and first part of quadratic form
# --> 168         covar = covar.evaluate_kernel()
#     169         inv_quad, logdet = covar.inv_quad_logdet(inv_quad_rhs=diff.unsqueeze(-1), logdet=True)
#     170
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/lazy/added_diag_lazy_tensor.py in evaluate_kernel(self)
#     185         In particular, covar1 would *always* be a standard AddedDiagLazyTensor, but covar2 might be a subtype.
#     186         """
# --> 187         added_diag_lazy_tsr = self.representation_tree()(*self.representation())
#     188         return added_diag_lazy_tsr._lazy_tensor + added_diag_lazy_tsr._diag_tensor
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/lazy/lazy_tensor.py in representation_tree(self)
#    1514         including all subobjects. This is used internally.
#    1515         """
# -> 1516         return LazyTensorRepresentationTree(self)
#    1517
#    1518     @property
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/lazy/lazy_tensor_representation_tree.py in __init__(self, lazy_tsr)
#      11         for arg in lazy_tsr._args:
#      12             if hasattr(arg, "representation") and callable(arg.representation):  # Is it a lazy tensor?
# ---> 13                 representation_size = len(arg.representation())
#      14                 self.children.append((slice(counter, counter + representation_size, None), arg.representation_tree()))
#      15                 counter += representation_size
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py in representation(self)
#     315         # representation
#     316         else:
# --> 317             return self.evaluate_kernel().representation()
#     318
#     319     def representation_tree(self):
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/utils/memoize.py in g(self, *args, **kwargs)
#      57         kwargs_pkl = pickle.dumps(kwargs)
#      58         if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59             return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60         return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#      61
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py in evaluate_kernel(self)
#     282             temp_active_dims = self.kernel.active_dims
#     283             self.kernel.active_dims = None
# --> 284             res = self.kernel(x1, x2, diag=False, last_dim_is_batch=self.last_dim_is_batch, **self.params)
#     285             self.kernel.active_dims = temp_active_dims
#     286
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/kernels/kernel.py in __call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     396                 res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     397             else:
# --> 398                 res = lazify(super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params))
#     399             return res
#     400
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/module.py in __call__(self, *inputs, **kwargs)
#      28
#      29     def __call__(self, *inputs, **kwargs):
# ---> 30         outputs = self.forward(*inputs, **kwargs)
#      31         if isinstance(outputs, list):
#      32             return [_validate_module_outputs(output) for output in outputs]
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/kernels/kernel.py in forward(self, x1, x2, diag, **params)
#     463         res = ZeroLazyTensor() if not diag else 0
#     464         for kern in self.kernels:
# --> 465             next_term = kern(x1, x2, diag=diag, **params)
#     466             if not diag:
#     467                 res = res + lazify(next_term)
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/kernels/kernel.py in __call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     396                 res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     397             else:
# --> 398                 res = lazify(super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params))
#     399             return res
#     400
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/module.py in __call__(self, *inputs, **kwargs)
#      28
#      29     def __call__(self, *inputs, **kwargs):
# ---> 30         outputs = self.forward(*inputs, **kwargs)
#      31         if isinstance(outputs, list):
#      32             return [_validate_module_outputs(output) for output in outputs]
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/kernels/scale_kernel.py in forward(self, x1, x2, last_dim_is_batch, diag, **params)
#      90
#      91     def forward(self, x1, x2, last_dim_is_batch=False, diag=False, **params):
# ---> 92         orig_output = self.base_kernel.forward(x1, x2, diag=diag, last_dim_is_batch=last_dim_is_batch, **params)
#      93         outputscales = self.outputscale
#      94         if last_dim_is_batch:
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gpytorch/kernels/periodic_kernel.py in forward(self, x1, x2, diag, **params)
#     117         x2_ = x2.div(self.period_length).mul(math.pi)
#     118         diff = x1_.unsqueeze(-2) - x2_.unsqueeze(-3)
# --> 119         res = diff.sin().pow(2).sum(dim=-1).div(self.lengthscale).mul(-2.0).exp_()
#     120         if diag:
#     121             res = res.squeeze(0)
#
# KeyboardInterrupt:

# %%
algorithm = 'mint'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            mint = hts.models.MinT(dataset=f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', 
                                   groups=groups,
                                   aggregate_key = '(State / Zone / Region) * Purpose')
            forecasts = mint.train()
            results = mint.results(forecasts)
            res = mint.metrics(results)
            mint.store_metrics(res)

# %%
algorithm = 'deepar'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            deepar = hts.models.DeepAR(dataset=f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups=groups)
            model = deepar.train()
            forecasts = deepar.predict(model)
            results = deepar.results(forecasts)
            res = deepar.metrics(results)
            deepar.store_metrics(res)
