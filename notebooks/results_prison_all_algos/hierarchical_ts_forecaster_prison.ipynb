# %%
import gpforecaster as gpf
import htsmodels as hts
import tsaugmentation as tsag
import matplotlib.pyplot as plt
import os
# Out:
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/json.py:45: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
dataset_name = 'prison'
dataset = tsag.preprocessing.PreprocessDatasets('prison')
groups = dataset.apply_preprocess()

# %%
# Store original results

for transf in ['jitter', 'time_warp', 'magnitude_warp', 'scaling']:
    algorithm = 'gpf'
    gpf_model = gpf.model.GPF(f'{dataset_name}_{algorithm}_{transf}_orig_s0', groups)
    model, like = gpf_model.train()
    mean, lower, upper = gpf_model.predict(model, like)
    res = gpf_model.metrics(mean)
    gpf_model.store_metrics(res)

    algorithm = 'mint'
    mint = hts.models.MinT(dataset=f'{dataset_name}_{algorithm}_{transf}_orig_s0', groups=groups)
    forecasts = mint.train()
    results = mint.results(forecasts)
    res = mint.metrics(results)
    mint.store_metrics(res)

    algorithm = 'deepar'
    deepar = hts.models.DeepAR(dataset=f'{dataset_name}_{algorithm}_{transf}_orig_s0', groups=groups)
    model = deepar.train()
    forecasts = deepar.predict(model)
    results = deepar.results(forecasts)
    res = deepar.metrics(results)
    deepar.store_metrics(res)
# Out:
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:00<00:00, 50.59it/s, epoch=1/100, avg_epoch_loss=5.77]
# 100%|██████████| 50/50 [00:00<00:00, 52.91it/s, epoch=2/100, avg_epoch_loss=5.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.20it/s, epoch=3/100, avg_epoch_loss=4.94]
# 100%|██████████| 50/50 [00:00<00:00, 52.82it/s, epoch=4/100, avg_epoch_loss=4.73]
# 100%|██████████| 50/50 [00:00<00:00, 53.74it/s, epoch=5/100, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 52.78it/s, epoch=6/100, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 54.73it/s, epoch=7/100, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 53.42it/s, epoch=8/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 53.17it/s, epoch=9/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 54.64it/s, epoch=10/100, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:00<00:00, 53.63it/s, epoch=11/100, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 53.70it/s, epoch=12/100, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 51.81it/s, epoch=13/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.01it/s, epoch=14/100, avg_epoch_loss=4.37]
# 100%|██████████| 50/50 [00:00<00:00, 51.40it/s, epoch=15/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 52.47it/s, epoch=16/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 52.17it/s, epoch=17/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.58it/s, epoch=18/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 52.21it/s, epoch=19/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 51.73it/s, epoch=20/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 52.31it/s, epoch=21/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 54.67it/s, epoch=22/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:00<00:00, 51.88it/s, epoch=23/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=24/100, avg_epoch_loss=4.36]
# 100%|██████████| 50/50 [00:00<00:00, 52.70it/s, epoch=25/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 52.55it/s, epoch=26/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 51.37it/s, epoch=27/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=28/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 52.40it/s, epoch=29/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 53.98it/s, epoch=30/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.40it/s, epoch=31/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 54.08it/s, epoch=32/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 53.42it/s, epoch=33/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=34/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:00<00:00, 51.59it/s, epoch=35/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=36/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.78it/s, epoch=37/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 52.80it/s, epoch=38/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 51.18it/s, epoch=39/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 53.46it/s, epoch=40/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:00<00:00, 53.18it/s, epoch=41/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 52.69it/s, epoch=42/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.01it/s, epoch=43/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 52.07it/s, epoch=44/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.29it/s, epoch=45/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 53.20it/s, epoch=46/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 52.34it/s, epoch=47/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=48/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 53.86it/s, epoch=49/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.60it/s, epoch=50/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:00<00:00, 51.80it/s, epoch=51/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 52.83it/s, epoch=52/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.63it/s, epoch=53/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 50.47it/s, epoch=54/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.80it/s, epoch=55/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.58it/s, epoch=56/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 51.61it/s, epoch=57/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 52.40it/s, epoch=58/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 53.26it/s, epoch=59/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 50.67it/s, epoch=60/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 51.78it/s, epoch=61/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.34it/s, epoch=62/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 50.78it/s, epoch=63/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 52.24it/s, epoch=64/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 51.84it/s, epoch=65/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 51.39it/s, epoch=66/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 53.31it/s, epoch=67/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.98it/s, epoch=68/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 51.61it/s, epoch=69/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 52.80it/s, epoch=70/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=71/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 54.01it/s, epoch=72/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 51.65it/s, epoch=73/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 51.71it/s, epoch=74/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 54.01it/s, epoch=75/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.13it/s, epoch=76/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 52.94it/s, epoch=77/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.97it/s, epoch=78/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.81it/s, epoch=79/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 54.10it/s, epoch=80/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 54.64it/s, epoch=81/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 51.90it/s, epoch=82/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 52.51it/s, epoch=83/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.89it/s, epoch=84/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:00<00:00, 52.39it/s, epoch=85/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 51.91it/s, epoch=86/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 52.81it/s, epoch=87/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 50.25it/s, epoch=88/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 51.96it/s, epoch=89/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 51.47it/s, epoch=90/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 52.24it/s, epoch=91/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 53.13it/s, epoch=92/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 52.18it/s, epoch=93/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 54.00it/s, epoch=94/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 53.51it/s, epoch=95/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 55.05it/s, epoch=96/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.97it/s, epoch=97/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 53.09it/s, epoch=98/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 53.31it/s, epoch=99/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 52.83it/s, epoch=100/100, avg_epoch_loss=4.12]
# 100%|██████████| 32/32 [00:00<00:00, 491.94it/s]
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:00<00:00, 52.67it/s, epoch=1/100, avg_epoch_loss=5.54]
# 100%|██████████| 50/50 [00:00<00:00, 54.46it/s, epoch=2/100, avg_epoch_loss=5.02]
# 100%|██████████| 50/50 [00:00<00:00, 51.23it/s, epoch=3/100, avg_epoch_loss=4.96]
# 100%|██████████| 50/50 [00:00<00:00, 51.45it/s, epoch=4/100, avg_epoch_loss=4.78]
# 100%|██████████| 50/50 [00:00<00:00, 52.28it/s, epoch=5/100, avg_epoch_loss=4.81]
# 100%|██████████| 50/50 [00:00<00:00, 52.12it/s, epoch=6/100, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 53.12it/s, epoch=7/100, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 51.57it/s, epoch=8/100, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 51.92it/s, epoch=9/100, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 51.02it/s, epoch=10/100, avg_epoch_loss=4.41]
# 100%|██████████| 50/50 [00:00<00:00, 52.36it/s, epoch=11/100, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:00<00:00, 54.26it/s, epoch=12/100, avg_epoch_loss=4.41]
# 100%|██████████| 50/50 [00:00<00:00, 51.97it/s, epoch=13/100, avg_epoch_loss=4.37]
# 100%|██████████| 50/50 [00:00<00:00, 52.88it/s, epoch=14/100, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:00<00:00, 51.99it/s, epoch=15/100, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:00<00:00, 52.50it/s, epoch=16/100, avg_epoch_loss=4.36]
# 100%|██████████| 50/50 [00:00<00:00, 52.18it/s, epoch=17/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:00<00:00, 52.57it/s, epoch=18/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:00<00:00, 52.93it/s, epoch=19/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:00<00:00, 53.14it/s, epoch=20/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:00<00:00, 53.55it/s, epoch=21/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 52.95it/s, epoch=22/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:00<00:00, 52.88it/s, epoch=23/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.20it/s, epoch=24/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 53.07it/s, epoch=25/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:00<00:00, 51.39it/s, epoch=26/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.01it/s, epoch=27/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 53.05it/s, epoch=28/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.55it/s, epoch=29/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.10it/s, epoch=30/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 52.21it/s, epoch=31/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.17it/s, epoch=32/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 54.09it/s, epoch=33/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.87it/s, epoch=34/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 52.22it/s, epoch=35/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 52.10it/s, epoch=36/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.74it/s, epoch=37/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 52.31it/s, epoch=38/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 51.23it/s, epoch=39/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 50.66it/s, epoch=40/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 51.37it/s, epoch=41/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 52.55it/s, epoch=42/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.08it/s, epoch=43/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 52.24it/s, epoch=44/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 52.38it/s, epoch=45/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.27it/s, epoch=46/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 52.08it/s, epoch=47/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.59it/s, epoch=48/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 53.77it/s, epoch=49/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 51.78it/s, epoch=50/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 51.83it/s, epoch=51/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:00<00:00, 53.02it/s, epoch=52/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:00<00:00, 54.68it/s, epoch=53/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 51.82it/s, epoch=54/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.21it/s, epoch=55/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:00<00:00, 53.23it/s, epoch=56/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 52.08it/s, epoch=57/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.51it/s, epoch=58/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 51.77it/s, epoch=59/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 53.43it/s, epoch=60/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 50.57it/s, epoch=61/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 52.56it/s, epoch=62/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:00<00:00, 52.84it/s, epoch=63/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 53.53it/s, epoch=64/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:00<00:00, 54.23it/s, epoch=65/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:00<00:00, 52.92it/s, epoch=66/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:00<00:00, 51.82it/s, epoch=67/100, avg_epoch_loss=4.02]
# 100%|██████████| 50/50 [00:00<00:00, 51.93it/s, epoch=68/100, avg_epoch_loss=4.03]
# 100%|██████████| 50/50 [00:00<00:00, 52.64it/s, epoch=69/100, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 52.60it/s, epoch=70/100, avg_epoch_loss=4.02]
# 100%|██████████| 50/50 [00:00<00:00, 52.77it/s, epoch=71/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:00<00:00, 53.22it/s, epoch=72/100, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 53.18it/s, epoch=73/100, avg_epoch_loss=4.06]
#  82%|████████▏ | 41/50 [00:00<00:00, 53.37it/s, epoch=74/100, avg_epoch_loss=3.97]WARNING:gluonts.trainer:Batch [45] of Epoch[73] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [46] of Epoch[73] gave NaN loss and it will be ignored
#  94%|█████████▍| 47/50 [00:00<00:00, 52.59it/s, epoch=74/100, avg_epoch_loss=3.9] WARNING:gluonts.trainer:Batch [48] of Epoch[73] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[73] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[73] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 54.06it/s, epoch=74/100, avg_epoch_loss=3.9]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[74] gave NaN loss and it will be ignored
#  18%|█▊        | 9/50 [00:00<00:00, 88.90it/s, epoch=75/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [10] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [11] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[74] gave NaN loss and it will be ignored
#  36%|███▌      | 18/50 [00:00<00:00, 88.47it/s, epoch=75/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [19] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [21] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [28] of Epoch[74] gave NaN loss and it will be ignored
#  56%|█████▌    | 28/50 [00:00<00:00, 89.97it/s, epoch=75/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [29] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [30] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [37] of Epoch[74] gave NaN loss and it will be ignored
#  74%|███████▍  | 37/50 [00:00<00:00, 89.72it/s, epoch=75/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [38] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [39] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [40] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [46] of Epoch[74] gave NaN loss and it will be ignored
#  92%|█████████▏| 46/50 [00:00<00:00, 87.76it/s, epoch=75/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [47] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[74] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[74] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 88.56it/s, epoch=75/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[75] gave NaN loss and it will be ignored
#  18%|█▊        | 9/50 [00:00<00:00, 87.29it/s, epoch=76/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [10] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [11] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[75] gave NaN loss and it will be ignored
#  36%|███▌      | 18/50 [00:00<00:00, 87.78it/s, epoch=76/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [19] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [21] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [28] of Epoch[75] gave NaN loss and it will be ignored
#  56%|█████▌    | 28/50 [00:00<00:00, 89.30it/s, epoch=76/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [29] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [30] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [37] of Epoch[75] gave NaN loss and it will be ignored
#  74%|███████▍  | 37/50 [00:00<00:00, 87.39it/s, epoch=76/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [38] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [39] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [40] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [46] of Epoch[75] gave NaN loss and it will be ignored
#  92%|█████████▏| 46/50 [00:00<00:00, 86.28it/s, epoch=76/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [47] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[75] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[75] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 86.99it/s, epoch=76/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [10] of Epoch[76] gave NaN loss and it will be ignored
#  20%|██        | 10/50 [00:00<00:00, 90.91it/s, epoch=77/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [11] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [19] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[76] gave NaN loss and it will be ignored
#  40%|████      | 20/50 [00:00<00:00, 87.03it/s, epoch=77/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [21] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [28] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [29] of Epoch[76] gave NaN loss and it will be ignored
#  58%|█████▊    | 29/50 [00:00<00:00, 85.54it/s, epoch=77/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [30] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [37] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [38] of Epoch[76] gave NaN loss and it will be ignored
#  76%|███████▌  | 38/50 [00:00<00:00, 84.47it/s, epoch=77/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [39] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [40] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [46] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [47] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[76] gave NaN loss and it will be ignored
#  96%|█████████▌| 48/50 [00:00<00:00, 86.57it/s, epoch=77/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [49] of Epoch[76] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[76] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 86.45it/s, epoch=77/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [10] of Epoch[77] gave NaN loss and it will be ignored
#  20%|██        | 10/50 [00:00<00:00, 90.34it/s, epoch=78/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [11] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [19] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[77] gave NaN loss and it will be ignored
#  40%|████      | 20/50 [00:00<00:00, 87.87it/s, epoch=78/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [21] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [28] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [29] of Epoch[77] gave NaN loss and it will be ignored
#  58%|█████▊    | 29/50 [00:00<00:00, 87.10it/s, epoch=78/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [30] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [37] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [38] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [39] of Epoch[77] gave NaN loss and it will be ignored
#  78%|███████▊  | 39/50 [00:00<00:00, 89.93it/s, epoch=78/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [40] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [46] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [47] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[77] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[77] gave NaN loss and it will be ignored
#  98%|█████████▊| 49/50 [00:00<00:00, 91.57it/s, epoch=78/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [50] of Epoch[77] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 90.06it/s, epoch=78/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[78] gave NaN loss and it will be ignored
#  18%|█▊        | 9/50 [00:00<00:00, 85.73it/s, epoch=79/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [10] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [11] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[78] gave NaN loss and it will be ignored
#  36%|███▌      | 18/50 [00:00<00:00, 86.88it/s, epoch=79/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [19] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [21] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[78] gave NaN loss and it will be ignored
#  54%|█████▍    | 27/50 [00:00<00:00, 85.25it/s, epoch=79/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [28] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [29] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [30] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[78] gave NaN loss and it will be ignored
#  72%|███████▏  | 36/50 [00:00<00:00, 83.53it/s, epoch=79/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [37] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [38] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [39] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [40] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[78] gave NaN loss and it will be ignored
#  90%|█████████ | 45/50 [00:00<00:00, 83.81it/s, epoch=79/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [46] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [47] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[78] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[78] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 84.53it/s, epoch=79/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]WARNING:gluonts.trainer:Batch [1] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [2] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [3] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [4] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [5] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [6] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [7] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [8] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [9] of Epoch[79] gave NaN loss and it will be ignored
#  18%|█▊        | 9/50 [00:00<00:00, 87.54it/s, epoch=80/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [10] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [11] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [12] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [13] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [14] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [15] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [16] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [17] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [18] of Epoch[79] gave NaN loss and it will be ignored
#  36%|███▌      | 18/50 [00:00<00:00, 88.21it/s, epoch=80/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [19] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [20] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [21] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [22] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [23] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [24] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [25] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [26] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [27] of Epoch[79] gave NaN loss and it will be ignored
#  54%|█████▍    | 27/50 [00:00<00:00, 88.66it/s, epoch=80/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [28] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [29] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [30] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [31] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [32] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [33] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [34] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [35] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [36] of Epoch[79] gave NaN loss and it will be ignored
#  72%|███████▏  | 36/50 [00:00<00:00, 88.72it/s, epoch=80/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [37] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [38] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [39] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [40] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [41] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [42] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [43] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [44] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [45] of Epoch[79] gave NaN loss and it will be ignored
#  90%|█████████ | 45/50 [00:00<00:00, 87.45it/s, epoch=80/100, avg_epoch_loss=nan]WARNING:gluonts.trainer:Batch [46] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [47] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [48] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [49] of Epoch[79] gave NaN loss and it will be ignored
# WARNING:gluonts.trainer:Batch [50] of Epoch[79] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 87.77it/s, epoch=80/100, avg_epoch_loss=nan]
# 100%|██████████| 32/32 [00:00<00:00, 511.10it/s]
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:00<00:00, 50.00it/s, epoch=1/100, avg_epoch_loss=5.61]
# 100%|██████████| 50/50 [00:00<00:00, 52.74it/s, epoch=2/100, avg_epoch_loss=5.14]
# 100%|██████████| 50/50 [00:00<00:00, 52.10it/s, epoch=3/100, avg_epoch_loss=4.84]
# 100%|██████████| 50/50 [00:00<00:00, 52.43it/s, epoch=4/100, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:00<00:00, 51.56it/s, epoch=5/100, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:00<00:00, 52.56it/s, epoch=6/100, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:00<00:00, 52.45it/s, epoch=7/100, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 51.97it/s, epoch=8/100, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 51.87it/s, epoch=9/100, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 54.19it/s, epoch=10/100, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:00<00:00, 52.14it/s, epoch=11/100, avg_epoch_loss=4.44]
# 100%|██████████| 50/50 [00:00<00:00, 51.78it/s, epoch=12/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 53.11it/s, epoch=13/100, avg_epoch_loss=4.36]
# 100%|██████████| 50/50 [00:00<00:00, 52.27it/s, epoch=14/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:00<00:00, 52.75it/s, epoch=15/100, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:00<00:00, 52.64it/s, epoch=16/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 50.99it/s, epoch=17/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.68it/s, epoch=18/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 55.75it/s, epoch=19/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:00<00:00, 50.88it/s, epoch=20/100, avg_epoch_loss=4.35]
# 100%|██████████| 50/50 [00:00<00:00, 54.27it/s, epoch=21/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:00<00:00, 54.75it/s, epoch=22/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 51.19it/s, epoch=23/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 51.96it/s, epoch=24/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 51.44it/s, epoch=25/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 52.51it/s, epoch=26/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 53.72it/s, epoch=27/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.30it/s, epoch=28/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.49it/s, epoch=29/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 52.98it/s, epoch=30/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.46it/s, epoch=31/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.21it/s, epoch=32/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.19it/s, epoch=33/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 52.61it/s, epoch=34/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=35/100, avg_epoch_loss=4.21]
# ...
# 100%|██████████| 50/50 [00:00<00:00, 54.40it/s, epoch=99/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 52.27it/s, epoch=100/100, avg_epoch_loss=4.09]
# 100%|██████████| 32/32 [00:00<00:00, 442.97it/s]
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:01<00:00, 47.48it/s, epoch=1/100, avg_epoch_loss=5.67]
# 100%|██████████| 50/50 [00:00<00:00, 53.10it/s, epoch=2/100, avg_epoch_loss=5.12]
# 100%|██████████| 50/50 [00:00<00:00, 51.84it/s, epoch=3/100, avg_epoch_loss=4.78]
# 100%|██████████| 50/50 [00:00<00:00, 51.82it/s, epoch=4/100, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:00<00:00, 51.52it/s, epoch=5/100, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 52.99it/s, epoch=6/100, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 53.25it/s, epoch=7/100, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 51.88it/s, epoch=8/100, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 52.88it/s, epoch=9/100, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 51.41it/s, epoch=10/100, avg_epoch_loss=4.42]
# 100%|██████████| 50/50 [00:00<00:00, 52.50it/s, epoch=11/100, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 51.84it/s, epoch=12/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:00<00:00, 52.88it/s, epoch=13/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.39it/s, epoch=14/100, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 52.65it/s, epoch=15/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:00<00:00, 52.07it/s, epoch=16/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 53.41it/s, epoch=17/100, avg_epoch_loss=4.37]
# 100%|██████████| 50/50 [00:00<00:00, 52.60it/s, epoch=18/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:00<00:00, 51.67it/s, epoch=19/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 52.66it/s, epoch=20/100, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:00<00:00, 51.62it/s, epoch=21/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 51.10it/s, epoch=22/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 53.31it/s, epoch=23/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:00<00:00, 51.58it/s, epoch=24/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.52it/s, epoch=25/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.77it/s, epoch=26/100, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:00<00:00, 53.16it/s, epoch=27/100, avg_epoch_loss=4.26]
# 100%|██████████| 50/50 [00:00<00:00, 51.57it/s, epoch=28/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 52.90it/s, epoch=29/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 51.14it/s, epoch=30/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 52.72it/s, epoch=31/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:00<00:00, 51.75it/s, epoch=32/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.20it/s, epoch=33/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.87it/s, epoch=34/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:00<00:00, 51.03it/s, epoch=35/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 51.52it/s, epoch=36/100, avg_epoch_loss=4.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.48it/s, epoch=37/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 54.88it/s, epoch=38/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 52.80it/s, epoch=39/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 55.30it/s, epoch=40/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 54.40it/s, epoch=41/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 52.13it/s, epoch=42/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:00<00:00, 53.28it/s, epoch=43/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 52.33it/s, epoch=44/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.97it/s, epoch=45/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 54.39it/s, epoch=46/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.93it/s, epoch=47/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:00<00:00, 54.53it/s, epoch=48/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.27it/s, epoch=49/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 54.17it/s, epoch=50/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 53.41it/s, epoch=51/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 53.89it/s, epoch=52/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.82it/s, epoch=53/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.85it/s, epoch=54/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 54.83it/s, epoch=55/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 52.39it/s, epoch=56/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 53.07it/s, epoch=57/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.16it/s, epoch=58/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 53.98it/s, epoch=59/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:00<00:00, 52.31it/s, epoch=60/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 55.34it/s, epoch=61/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.54it/s, epoch=62/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.72it/s, epoch=63/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.43it/s, epoch=64/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 54.45it/s, epoch=65/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 51.33it/s, epoch=66/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 52.44it/s, epoch=67/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.35it/s, epoch=68/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 53.30it/s, epoch=69/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=70/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 51.61it/s, epoch=71/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=72/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.26it/s, epoch=73/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.04it/s, epoch=74/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.52it/s, epoch=75/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.86it/s, epoch=76/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 53.22it/s, epoch=77/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 51.58it/s, epoch=78/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.80it/s, epoch=79/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 52.74it/s, epoch=80/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:00<00:00, 52.99it/s, epoch=81/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 54.68it/s, epoch=82/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 53.58it/s, epoch=83/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 54.05it/s, epoch=84/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 52.55it/s, epoch=85/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=86/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:00<00:00, 54.08it/s, epoch=87/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 52.14it/s, epoch=88/100, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.88it/s, epoch=89/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 53.46it/s, epoch=90/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:00<00:00, 51.94it/s, epoch=91/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 54.32it/s, epoch=92/100, avg_epoch_loss=4.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.10it/s, epoch=93/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:00<00:00, 51.73it/s, epoch=94/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:00<00:00, 54.34it/s, epoch=95/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 55.04it/s, epoch=96/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 54.13it/s, epoch=97/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:00<00:00, 53.34it/s, epoch=98/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.69it/s, epoch=99/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 55.38it/s, epoch=100/100, avg_epoch_loss=4.15]
# 100%|██████████| 32/32 [00:00<00:00, 495.87it/s]
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# 100%|██████████| 50/50 [00:00<00:00, 50.21it/s, epoch=1/100, avg_epoch_loss=5.58]
# 100%|██████████| 50/50 [00:00<00:00, 52.40it/s, epoch=2/100, avg_epoch_loss=5.19]
# 100%|██████████| 50/50 [00:00<00:00, 50.85it/s, epoch=3/100, avg_epoch_loss=4.98]
# 100%|██████████| 50/50 [00:00<00:00, 50.76it/s, epoch=4/100, avg_epoch_loss=4.91]
# 100%|██████████| 50/50 [00:00<00:00, 51.30it/s, epoch=5/100, avg_epoch_loss=4.81]
# 100%|██████████| 50/50 [00:00<00:00, 52.62it/s, epoch=6/100, avg_epoch_loss=4.74]
# 100%|██████████| 50/50 [00:00<00:00, 51.49it/s, epoch=7/100, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 53.53it/s, epoch=8/100, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:00<00:00, 51.85it/s, epoch=9/100, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 50.90it/s, epoch=10/100, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 52.16it/s, epoch=11/100, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 51.55it/s, epoch=12/100, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 50.48it/s, epoch=13/100, avg_epoch_loss=4.48]
#  74%|███████▍  | 37/50 [00:00<00:00, 51.26it/s, epoch=14/100, avg_epoch_loss=4.44]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-293c7cb35b87> in <module>
#      19         algorithm = 'deepar'
#      20         deepar = hts.models.DeepAR(dataset=f'{dataset_name}_{algorithm}_{transf}_orig_s{j}', groups=groups)
# ---> 21         model = deepar.train()
#      22         forecasts = deepar.predict(model)
#      23         results = deepar.results(forecasts)
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/deepar.py in train(self, lr, epochs)
#      70         )
#      71
# ---> 72         model = estimator.train(train_ds)
#      73         return model
#      74
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/mx/model/estimator.py in train(self, training_data, validation_data, num_workers, num_prefetch, shuffle_buffer_length, cache_data, **kwargs)
#     193         **kwargs,
#     194     ) -> Predictor:
# --> 195         return self.train_model(
#     196             training_data=training_data,
#     197             validation_data=validation_data,
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/mx/model/estimator.py in train_model(self, training_data, validation_data, num_workers, num_prefetch, shuffle_buffer_length, cache_data)
#     168         training_network = self.create_training_network()
#     169
# --> 170         self.trainer(
#     171             net=training_network,
#     172             train_iter=training_data_loader,
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/mx/trainer/_base.py in __call__(self, net, train_iter, validation_iter)
#     434                 logger.info(f"Epoch[{epoch_no}] Learning rate is {curr_lr}")
#     435
# --> 436                 epoch_loss = loop(
#     437                     epoch_no,
#     438                     train_iter,
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/mx/trainer/_base.py in loop(epoch_no, batch_iter, num_batches_to_use, is_training)
#     323
#     324                 it = tqdm(batch_iter, total=num_batches_to_use)
# --> 325                 for batch_no, batch in enumerate(it, start=1):
#     326                     # `batch` here is expected to be a dictionary whose fields
#     327                     # should correspond 1-to-1 with the network inputs
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/tqdm/std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/_base.py in __iter__(self)
#     101
#     102     def __iter__(self) -> Iterator[DataEntry]:
# --> 103         yield from self.transformation(
#     104             self.base_dataset, is_train=self.is_train
#     105         )
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/_base.py in __call__(self, data_it, is_train)
#     121         self, data_it: Iterable[DataEntry], is_train: bool
#     122     ) -> Iterator:
# --> 123         for data_entry in data_it:
#     124             try:
#     125                 yield self.map_transform(data_entry.copy(), is_train)
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/dataset/loader.py in __call__(self, data, is_train)
#     136
#     137     def __call__(self, data, is_train):
# --> 138         yield from batcher(data, self.batch_size)
#     139
#     140
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/itertools.py in get_batch()
#      62
#      63     def get_batch():
# ---> 64         return list(itertools.islice(it, batch_size))
#      65
#      66     # has an empty list so that we have a 2D array for sure
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/_base.py in __call__(self, data_it, is_train)
#     121         self, data_it: Iterable[DataEntry], is_train: bool
#     122     ) -> Iterator:
# --> 123         for data_entry in data_it:
#     124             try:
#     125                 yield self.map_transform(data_entry.copy(), is_train)
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/_base.py in __call__(self, data_it, is_train)
#     176         for data_entry in data_it:
#     177             num_idle_transforms += 1
# --> 178             for result in self.flatmap_transform(data_entry.copy(), is_train):
#     179                 num_idle_transforms = 0
#     180                 yield result
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/split.py in flatmap_transform(self, data, is_train)
#     155         target = data[self.target_field]
#     156
# --> 157         sampled_indices = self.instance_sampler(target)
#     158
#     159         for i in sampled_indices:
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/sampler.py in __call__(self, ts)
#     123
#     124     def __call__(self, ts: np.ndarray) -> np.ndarray:
# --> 125         a, b = self._get_bounds(ts)
#     126         window_size = b - a + 1
#     127
#
# ~/anaconda3/envs/gpytorch/lib/python3.9/site-packages/gluonts/transform/sampler.py in _get_bounds(self, ts)
#      39         return (
#      40             self.min_past,
# ---> 41             ts.shape[self.axis] - self.min_future,
#      42         )
#      43
#
# KeyboardInterrupt:

# %%
#prison = tsag.transformations.CreateTransformedVersions('prison')
#prison.create_new_version_single_transf()

# %%
vis = tsag.visualization.Visualizer('prison')

# %%
algorithm = 'gpf'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            gpf_model = gpf.model.GPF(f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups)
            model, like = gpf_model.train()
            mean, lower, upper = gpf_model.predict(model, like)
            res = gpf_model.metrics(mean)
            gpf_model.store_metrics(res)

# %%
algorithm = 'mint'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            mint = hts.models.MinT(dataset=f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups=groups)
            forecasts = mint.train()
            results = mint.results(forecasts)
            res = mint.metrics(results)
            mint.store_metrics(res)
# Out:
# R[write to console]: ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────── fpp3 0.4.0 ──
#
# R[write to console]: ✔ tibble      3.1.5      ✔ tsibble     1.1.1
# ✔ dplyr       1.0.7      ✔ tsibbledata 0.3.0
# ✔ tidyr       1.1.4      ✔ feasts      0.2.2
# ✔ lubridate   1.7.10     ✔ fable       0.3.1
# ✔ ggplot2     3.3.5
#
# R[write to console]: ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()
#
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# ...
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")
# /home/mach2ne/anaconda3/envs/gpytorch/lib/python3.9/site-packages/htsmodels/models/mint.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_mint[group] = pred_mint[group].astype("category")

# %%
algorithm = 'deepar'
for k in ['jitter', 'scaling', 'magnitude_warp', 'time_warp']:
    vis._read_files(f'single_transf_{k}')
    for i in range(6):
        for j in range(10):
            groups['train']['data'] = vis.y_new[i, j]
            deepar = hts.models.DeepAR(dataset=f'{dataset_name}_{algorithm}_{k}_v{i}_s{j}', groups=groups)
            model = deepar.train()
            forecasts = deepar.predict(model)
            results = deepar.results(forecasts)
            res = deepar.metrics(results)
            deepar.store_metrics(res)
