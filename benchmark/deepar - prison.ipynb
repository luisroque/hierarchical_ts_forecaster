# %%
import warnings
import pandas as pd
import arviz as az

import os, sys
dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
if not dir1 in sys.path: sys.path.append(dir1)
from libs.metrics import calculate_metrics, metrics_to_table, metrics_to_latex
from libs.pre_processing import generate_groups_data_flat
from libs.visual_analysis import visualize_fit, visualize_predict, traceplot, visualize_prior, plot_elbo, plot_gps_components, model_graph
from libs.model import HGPforecaster
import numpy as np
from tqdm.autonotebook import tqdm
import matplotlib.pyplot as plt
az.style.use('arviz-darkgrid')
warnings.filterwarnings('ignore')
import json

import theano
theano.config.compute_test_value='raise'
# Out:
# /home/mach1ne/anaconda3/envs/phd_clean/lib/python3.7/site-packages/ipykernel_launcher.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
single_prediction_length = 8
submission_prediction_length = single_prediction_length * 2
input_path="../data/"
submission=False

if submission:
    prediction_length = submission_prediction_length
else:
    prediction_length = single_prediction_length

# %%
prison = pd.read_csv('../data/prisonLF.csv', sep=",")
prison = prison.drop('Unnamed: 0', axis =1)
prison['t'] = prison['t'].astype('datetime64[ns]')

# %%
prison_pivot = prison.pivot(index='t',columns=['state', 'gender', 'legal'], values='count').T

# %%
prison = prison_pivot.reset_index()

# %%
state_ids = prison["state"].astype('category').cat.codes.values
state_ids_un , state_ids_counts = np.unique(state_ids, return_counts=True)

gender_ids = prison["gender"].astype('category').cat.codes.values
gender_ids_un , gender_ids_counts = np.unique(gender_ids, return_counts=True)

legal_ids = prison["legal"].astype('category').cat.codes.values
legal_ids_un , legal_ids_counts = np.unique(legal_ids, return_counts=True)

stat_cat = np.concatenate((state_ids.reshape(-1,1), gender_ids.reshape(-1,1), legal_ids.reshape(-1,1)), axis=1)

stat_cat_cardinalities = [len(state_ids_un), len(gender_ids_un), len(legal_ids_un)]

# %%
from gluonts.dataset.common import load_datasets, ListDataset
from gluonts.dataset.field_names import FieldName

prison_dates = [pd.Timestamp("2005-03-01", freq='1Q') for _ in range(prison.shape[0])]

# %%
train_target_values = prison_pivot.values
test_target_values = train_target_values.copy()
train_target_values = [ts[:-single_prediction_length] for ts in prison_pivot.values]

# %%
train_ds = ListDataset([
    {
        FieldName.TARGET: target,
        FieldName.START: start,
        FieldName.FEAT_STATIC_CAT: fsc
    }
    for (target, start, fsc) in zip(train_target_values,
                                         prison_dates,
                                         stat_cat)
], freq="Q")

test_ds = ListDataset([
    {
        FieldName.TARGET: target,
        FieldName.START: start,
        FieldName.FEAT_STATIC_CAT: fsc
    }
    for (target, start, fsc) in zip(test_target_values,
                                         prison_dates,
                                         stat_cat)
], freq="Q")

# %%
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx.distribution.neg_binomial import NegativeBinomialOutput
from gluonts.mx.trainer import Trainer

estimator = DeepAREstimator(
    prediction_length=prediction_length,
    freq="Q",
    distr_output = NegativeBinomialOutput(),
    use_feat_dynamic_real=False,
    use_feat_static_cat=True,
    cardinality=stat_cat_cardinalities,
    trainer=Trainer(
        learning_rate=1e-3,
        epochs=100,
        num_batches_per_epoch=50,
        batch_size=32
    )
)

predictor = estimator.train(train_ds)
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 37.28it/s, epoch=1/100, avg_epoch_loss=5.57]
# 100%|██████████| 50/50 [00:01<00:00, 39.37it/s, epoch=2/100, avg_epoch_loss=5.07]
# 100%|██████████| 50/50 [00:01<00:00, 39.00it/s, epoch=3/100, avg_epoch_loss=4.79]
# 100%|██████████| 50/50 [00:01<00:00, 41.67it/s, epoch=4/100, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:01<00:00, 38.84it/s, epoch=5/100, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:01<00:00, 39.60it/s, epoch=6/100, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:01<00:00, 40.37it/s, epoch=7/100, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:01<00:00, 39.82it/s, epoch=8/100, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:01<00:00, 35.42it/s, epoch=9/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:01<00:00, 34.78it/s, epoch=10/100, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:01<00:00, 31.79it/s, epoch=11/100, avg_epoch_loss=4.37]
# 100%|██████████| 50/50 [00:01<00:00, 33.99it/s, epoch=12/100, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:01<00:00, 36.20it/s, epoch=13/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:01<00:00, 39.93it/s, epoch=14/100, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:01<00:00, 41.77it/s, epoch=15/100, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:01<00:00, 39.81it/s, epoch=16/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:01<00:00, 40.00it/s, epoch=17/100, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:01<00:00, 39.62it/s, epoch=18/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:01<00:00, 34.89it/s, epoch=19/100, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:01<00:00, 32.75it/s, epoch=20/100, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:01<00:00, 34.78it/s, epoch=21/100, avg_epoch_loss=4.37]
# 100%|██████████| 50/50 [00:01<00:00, 34.03it/s, epoch=22/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:01<00:00, 33.05it/s, epoch=23/100, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:01<00:00, 35.70it/s, epoch=24/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:01<00:00, 34.78it/s, epoch=25/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:01<00:00, 33.93it/s, epoch=26/100, avg_epoch_loss=4.24]
# 100%|██████████| 50/50 [00:01<00:00, 35.56it/s, epoch=27/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:01<00:00, 38.80it/s, epoch=28/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:01<00:00, 41.32it/s, epoch=29/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:01<00:00, 39.05it/s, epoch=30/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:01<00:00, 41.77it/s, epoch=31/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:01<00:00, 39.67it/s, epoch=32/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:01<00:00, 41.55it/s, epoch=33/100, avg_epoch_loss=4.23]
# 100%|██████████| 50/50 [00:01<00:00, 38.03it/s, epoch=34/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:01<00:00, 41.52it/s, epoch=35/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:01<00:00, 38.44it/s, epoch=36/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:01<00:00, 36.68it/s, epoch=37/100, avg_epoch_loss=4.1]
# 100%|██████████| 50/50 [00:01<00:00, 32.70it/s, epoch=38/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:01<00:00, 39.46it/s, epoch=39/100, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:01<00:00, 36.92it/s, epoch=40/100, avg_epoch_loss=4.17]
# 100%|██████████| 50/50 [00:01<00:00, 41.53it/s, epoch=41/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:01<00:00, 36.92it/s, epoch=42/100, avg_epoch_loss=4.15]
# 100%|██████████| 50/50 [00:01<00:00, 40.66it/s, epoch=43/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:01<00:00, 43.42it/s, epoch=44/100, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:01<00:00, 41.95it/s, epoch=45/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:01<00:00, 42.63it/s, epoch=46/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:01<00:00, 42.23it/s, epoch=47/100, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:01<00:00, 42.04it/s, epoch=48/100, avg_epoch_loss=4.13]
# 100%|██████████| 50/50 [00:01<00:00, 42.86it/s, epoch=49/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:01<00:00, 41.73it/s, epoch=50/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 43.48it/s, epoch=51/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:01<00:00, 41.60it/s, epoch=52/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:01<00:00, 43.91it/s, epoch=53/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 45.60it/s, epoch=54/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 43.40it/s, epoch=55/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 42.93it/s, epoch=56/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 41.17it/s, epoch=57/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 42.69it/s, epoch=58/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 42.21it/s, epoch=59/100, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:01<00:00, 42.64it/s, epoch=60/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 42.87it/s, epoch=61/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:01<00:00, 42.41it/s, epoch=62/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 44.72it/s, epoch=63/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 42.20it/s, epoch=64/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:01<00:00, 42.32it/s, epoch=65/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 40.92it/s, epoch=66/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 43.06it/s, epoch=67/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 41.42it/s, epoch=68/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:01<00:00, 44.00it/s, epoch=69/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 41.81it/s, epoch=70/100, avg_epoch_loss=4.07]
# 100%|██████████| 50/50 [00:01<00:00, 42.08it/s, epoch=71/100, avg_epoch_loss=4.03]
# 100%|██████████| 50/50 [00:01<00:00, 42.73it/s, epoch=72/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 43.81it/s, epoch=73/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 43.02it/s, epoch=74/100, avg_epoch_loss=4.01]
# 100%|██████████| 50/50 [00:01<00:00, 43.59it/s, epoch=75/100, avg_epoch_loss=4.04]
# 100%|██████████| 50/50 [00:01<00:00, 42.76it/s, epoch=76/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:01<00:00, 41.94it/s, epoch=77/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:01<00:00, 42.49it/s, epoch=78/100, avg_epoch_loss=4.02]
# 100%|██████████| 50/50 [00:01<00:00, 42.36it/s, epoch=79/100, avg_epoch_loss=4.01]
# 100%|██████████| 50/50 [00:01<00:00, 43.42it/s, epoch=80/100, avg_epoch_loss=4.05]
# 100%|██████████| 50/50 [00:01<00:00, 42.57it/s, epoch=81/100, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:01<00:00, 43.22it/s, epoch=82/100, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:01<00:00, 42.48it/s, epoch=83/100, avg_epoch_loss=3.99]
# 100%|██████████| 50/50 [00:01<00:00, 42.58it/s, epoch=84/100, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:01<00:00, 42.88it/s, epoch=85/100, avg_epoch_loss=3.99]
# 100%|██████████| 50/50 [00:01<00:00, 41.76it/s, epoch=86/100, avg_epoch_loss=4.04]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [45] of Epoch[86] gave NaN loss and it will be ignored
# Batch [46] of Epoch[86] gave NaN loss and it will be ignored
# Batch [47] of Epoch[86] gave NaN loss and it will be ignored
# Batch [48] of Epoch[86] gave NaN loss and it will be ignored
# Batch [49] of Epoch[86] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:01<00:00, 44.23it/s, epoch=87/100, avg_epoch_loss=3.86]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [1] of Epoch[87] gave NaN loss and it will be ignored
# Batch [2] of Epoch[87] gave NaN loss and it will be ignored
# Batch [3] of Epoch[87] gave NaN loss and it will be ignored
# Batch [4] of Epoch[87] gave NaN loss and it will be ignored
# Batch [5] of Epoch[87] gave NaN loss and it will be ignored
# Batch [6] of Epoch[87] gave NaN loss and it will be ignored
# Batch [7] of Epoch[87] gave NaN loss and it will be ignored
# Batch [8] of Epoch[87] gave NaN loss and it will be ignored
# Batch [9] of Epoch[87] gave NaN loss and it will be ignored
# Batch [10] of Epoch[87] gave NaN loss and it will be ignored
# Batch [11] of Epoch[87] gave NaN loss and it will be ignored
# Batch [12] of Epoch[87] gave NaN loss and it will be ignored
# Batch [13] of Epoch[87] gave NaN loss and it will be ignored
# Batch [14] of Epoch[87] gave NaN loss and it will be ignored
# Batch [15] of Epoch[87] gave NaN loss and it will be ignored
# Batch [16] of Epoch[87] gave NaN loss and it will be ignored
# Batch [17] of Epoch[87] gave NaN loss and it will be ignored
# Batch [18] of Epoch[87] gave NaN loss and it will be ignored
# Batch [19] of Epoch[87] gave NaN loss and it will be ignored
# Batch [20] of Epoch[87] gave NaN loss and it will be ignored
# Batch [21] of Epoch[87] gave NaN loss and it will be ignored
# Batch [22] of Epoch[87] gave NaN loss and it will be ignored
# Batch [23] of Epoch[87] gave NaN loss and it will be ignored
# Batch [24] of Epoch[87] gave NaN loss and it will be ignored
# Batch [25] of Epoch[87] gave NaN loss and it will be ignored
# Batch [26] of Epoch[87] gave NaN loss and it will be ignored
# Batch [27] of Epoch[87] gave NaN loss and it will be ignored
# Batch [28] of Epoch[87] gave NaN loss and it will be ignored
# Batch [29] of Epoch[87] gave NaN loss and it will be ignored
# Batch [30] of Epoch[87] gave NaN loss and it will be ignored
# Batch [31] of Epoch[87] gave NaN loss and it will be ignored
# Batch [32] of Epoch[87] gave NaN loss and it will be ignored
# Batch [33] of Epoch[87] gave NaN loss and it will be ignored
# Batch [34] of Epoch[87] gave NaN loss and it will be ignored
# Batch [35] of Epoch[87] gave NaN loss and it will be ignored
# Batch [36] of Epoch[87] gave NaN loss and it will be ignored
# Batch [37] of Epoch[87] gave NaN loss and it will be ignored
# Batch [38] of Epoch[87] gave NaN loss and it will be ignored
# Batch [39] of Epoch[87] gave NaN loss and it will be ignored
# Batch [40] of Epoch[87] gave NaN loss and it will be ignored
# Batch [41] of Epoch[87] gave NaN loss and it will be ignored
# Batch [42] of Epoch[87] gave NaN loss and it will be ignored
# Batch [43] of Epoch[87] gave NaN loss and it will be ignored
# Batch [44] of Epoch[87] gave NaN loss and it will be ignored
# Batch [45] of Epoch[87] gave NaN loss and it will be ignored
# Batch [46] of Epoch[87] gave NaN loss and it will be ignored
# Batch [47] of Epoch[87] gave NaN loss and it will be ignored
# Batch [48] of Epoch[87] gave NaN loss and it will be ignored
# Batch [49] of Epoch[87] gave NaN loss and it will be ignored
# Batch [50] of Epoch[87] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 62.13it/s, epoch=88/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [1] of Epoch[88] gave NaN loss and it will be ignored
# Batch [2] of Epoch[88] gave NaN loss and it will be ignored
# Batch [3] of Epoch[88] gave NaN loss and it will be ignored
# Batch [4] of Epoch[88] gave NaN loss and it will be ignored
# Batch [5] of Epoch[88] gave NaN loss and it will be ignored
# Batch [6] of Epoch[88] gave NaN loss and it will be ignored
# Batch [7] of Epoch[88] gave NaN loss and it will be ignored
# Batch [8] of Epoch[88] gave NaN loss and it will be ignored
# Batch [9] of Epoch[88] gave NaN loss and it will be ignored
# Batch [10] of Epoch[88] gave NaN loss and it will be ignored
# Batch [11] of Epoch[88] gave NaN loss and it will be ignored
# Batch [12] of Epoch[88] gave NaN loss and it will be ignored
# Batch [13] of Epoch[88] gave NaN loss and it will be ignored
# Batch [14] of Epoch[88] gave NaN loss and it will be ignored
# Batch [15] of Epoch[88] gave NaN loss and it will be ignored
# Batch [16] of Epoch[88] gave NaN loss and it will be ignored
# Batch [17] of Epoch[88] gave NaN loss and it will be ignored
# Batch [18] of Epoch[88] gave NaN loss and it will be ignored
# Batch [19] of Epoch[88] gave NaN loss and it will be ignored
# Batch [20] of Epoch[88] gave NaN loss and it will be ignored
# Batch [21] of Epoch[88] gave NaN loss and it will be ignored
# Batch [22] of Epoch[88] gave NaN loss and it will be ignored
# Batch [23] of Epoch[88] gave NaN loss and it will be ignored
# Batch [24] of Epoch[88] gave NaN loss and it will be ignored
# Batch [25] of Epoch[88] gave NaN loss and it will be ignored
# Batch [26] of Epoch[88] gave NaN loss and it will be ignored
# Batch [27] of Epoch[88] gave NaN loss and it will be ignored
# Batch [28] of Epoch[88] gave NaN loss and it will be ignored
# Batch [29] of Epoch[88] gave NaN loss and it will be ignored
# Batch [30] of Epoch[88] gave NaN loss and it will be ignored
# Batch [31] of Epoch[88] gave NaN loss and it will be ignored
# Batch [32] of Epoch[88] gave NaN loss and it will be ignored
# Batch [33] of Epoch[88] gave NaN loss and it will be ignored
# Batch [34] of Epoch[88] gave NaN loss and it will be ignored
# Batch [35] of Epoch[88] gave NaN loss and it will be ignored
# Batch [36] of Epoch[88] gave NaN loss and it will be ignored
# Batch [37] of Epoch[88] gave NaN loss and it will be ignored
# Batch [38] of Epoch[88] gave NaN loss and it will be ignored
# Batch [39] of Epoch[88] gave NaN loss and it will be ignored
# Batch [40] of Epoch[88] gave NaN loss and it will be ignored
# Batch [41] of Epoch[88] gave NaN loss and it will be ignored
# Batch [42] of Epoch[88] gave NaN loss and it will be ignored
# Batch [43] of Epoch[88] gave NaN loss and it will be ignored
# Batch [44] of Epoch[88] gave NaN loss and it will be ignored
# Batch [45] of Epoch[88] gave NaN loss and it will be ignored
# Batch [46] of Epoch[88] gave NaN loss and it will be ignored
# Batch [47] of Epoch[88] gave NaN loss and it will be ignored
# Batch [48] of Epoch[88] gave NaN loss and it will be ignored
# Batch [49] of Epoch[88] gave NaN loss and it will be ignored
# Batch [50] of Epoch[88] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 61.00it/s, epoch=89/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [1] of Epoch[89] gave NaN loss and it will be ignored
# Batch [2] of Epoch[89] gave NaN loss and it will be ignored
# Batch [3] of Epoch[89] gave NaN loss and it will be ignored
# Batch [4] of Epoch[89] gave NaN loss and it will be ignored
# Batch [5] of Epoch[89] gave NaN loss and it will be ignored
# Batch [6] of Epoch[89] gave NaN loss and it will be ignored
# Batch [7] of Epoch[89] gave NaN loss and it will be ignored
# Batch [8] of Epoch[89] gave NaN loss and it will be ignored
# Batch [9] of Epoch[89] gave NaN loss and it will be ignored
# Batch [10] of Epoch[89] gave NaN loss and it will be ignored
# Batch [11] of Epoch[89] gave NaN loss and it will be ignored
# Batch [12] of Epoch[89] gave NaN loss and it will be ignored
# Batch [13] of Epoch[89] gave NaN loss and it will be ignored
# Batch [14] of Epoch[89] gave NaN loss and it will be ignored
# Batch [15] of Epoch[89] gave NaN loss and it will be ignored
# Batch [16] of Epoch[89] gave NaN loss and it will be ignored
# Batch [17] of Epoch[89] gave NaN loss and it will be ignored
# Batch [18] of Epoch[89] gave NaN loss and it will be ignored
# Batch [19] of Epoch[89] gave NaN loss and it will be ignored
# Batch [20] of Epoch[89] gave NaN loss and it will be ignored
# Batch [21] of Epoch[89] gave NaN loss and it will be ignored
# Batch [22] of Epoch[89] gave NaN loss and it will be ignored
# Batch [23] of Epoch[89] gave NaN loss and it will be ignored
# Batch [24] of Epoch[89] gave NaN loss and it will be ignored
# Batch [25] of Epoch[89] gave NaN loss and it will be ignored
# Batch [26] of Epoch[89] gave NaN loss and it will be ignored
# Batch [27] of Epoch[89] gave NaN loss and it will be ignored
# Batch [28] of Epoch[89] gave NaN loss and it will be ignored
# Batch [29] of Epoch[89] gave NaN loss and it will be ignored
# Batch [30] of Epoch[89] gave NaN loss and it will be ignored
# Batch [31] of Epoch[89] gave NaN loss and it will be ignored
# Batch [32] of Epoch[89] gave NaN loss and it will be ignored
# Batch [33] of Epoch[89] gave NaN loss and it will be ignored
# Batch [34] of Epoch[89] gave NaN loss and it will be ignored
# Batch [35] of Epoch[89] gave NaN loss and it will be ignored
# Batch [36] of Epoch[89] gave NaN loss and it will be ignored
# Batch [37] of Epoch[89] gave NaN loss and it will be ignored
# Batch [38] of Epoch[89] gave NaN loss and it will be ignored
# Batch [39] of Epoch[89] gave NaN loss and it will be ignored
# Batch [40] of Epoch[89] gave NaN loss and it will be ignored
# Batch [41] of Epoch[89] gave NaN loss and it will be ignored
# Batch [42] of Epoch[89] gave NaN loss and it will be ignored
# Batch [43] of Epoch[89] gave NaN loss and it will be ignored
# Batch [44] of Epoch[89] gave NaN loss and it will be ignored
# Batch [45] of Epoch[89] gave NaN loss and it will be ignored
# Batch [46] of Epoch[89] gave NaN loss and it will be ignored
# Batch [47] of Epoch[89] gave NaN loss and it will be ignored
# Batch [48] of Epoch[89] gave NaN loss and it will be ignored
# Batch [49] of Epoch[89] gave NaN loss and it will be ignored
# Batch [50] of Epoch[89] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 62.44it/s, epoch=90/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [1] of Epoch[90] gave NaN loss and it will be ignored
# Batch [2] of Epoch[90] gave NaN loss and it will be ignored
# Batch [3] of Epoch[90] gave NaN loss and it will be ignored
# Batch [4] of Epoch[90] gave NaN loss and it will be ignored
# Batch [5] of Epoch[90] gave NaN loss and it will be ignored
# Batch [6] of Epoch[90] gave NaN loss and it will be ignored
# Batch [7] of Epoch[90] gave NaN loss and it will be ignored
# Batch [8] of Epoch[90] gave NaN loss and it will be ignored
# Batch [9] of Epoch[90] gave NaN loss and it will be ignored
# Batch [10] of Epoch[90] gave NaN loss and it will be ignored
# Batch [11] of Epoch[90] gave NaN loss and it will be ignored
# Batch [12] of Epoch[90] gave NaN loss and it will be ignored
# Batch [13] of Epoch[90] gave NaN loss and it will be ignored
# Batch [14] of Epoch[90] gave NaN loss and it will be ignored
# Batch [15] of Epoch[90] gave NaN loss and it will be ignored
# Batch [16] of Epoch[90] gave NaN loss and it will be ignored
# Batch [17] of Epoch[90] gave NaN loss and it will be ignored
# Batch [18] of Epoch[90] gave NaN loss and it will be ignored
# Batch [19] of Epoch[90] gave NaN loss and it will be ignored
# Batch [20] of Epoch[90] gave NaN loss and it will be ignored
# Batch [21] of Epoch[90] gave NaN loss and it will be ignored
# Batch [22] of Epoch[90] gave NaN loss and it will be ignored
# Batch [23] of Epoch[90] gave NaN loss and it will be ignored
# Batch [24] of Epoch[90] gave NaN loss and it will be ignored
# Batch [25] of Epoch[90] gave NaN loss and it will be ignored
# Batch [26] of Epoch[90] gave NaN loss and it will be ignored
# Batch [27] of Epoch[90] gave NaN loss and it will be ignored
# Batch [28] of Epoch[90] gave NaN loss and it will be ignored
# Batch [29] of Epoch[90] gave NaN loss and it will be ignored
# Batch [30] of Epoch[90] gave NaN loss and it will be ignored
# Batch [31] of Epoch[90] gave NaN loss and it will be ignored
# Batch [32] of Epoch[90] gave NaN loss and it will be ignored
# Batch [33] of Epoch[90] gave NaN loss and it will be ignored
# Batch [34] of Epoch[90] gave NaN loss and it will be ignored
# Batch [35] of Epoch[90] gave NaN loss and it will be ignored
# Batch [36] of Epoch[90] gave NaN loss and it will be ignored
# Batch [37] of Epoch[90] gave NaN loss and it will be ignored
# Batch [38] of Epoch[90] gave NaN loss and it will be ignored
# Batch [39] of Epoch[90] gave NaN loss and it will be ignored
# Batch [40] of Epoch[90] gave NaN loss and it will be ignored
# Batch [41] of Epoch[90] gave NaN loss and it will be ignored
# Batch [42] of Epoch[90] gave NaN loss and it will be ignored
# Batch [43] of Epoch[90] gave NaN loss and it will be ignored
# Batch [44] of Epoch[90] gave NaN loss and it will be ignored
# Batch [45] of Epoch[90] gave NaN loss and it will be ignored
# Batch [46] of Epoch[90] gave NaN loss and it will be ignored
# Batch [47] of Epoch[90] gave NaN loss and it will be ignored
# Batch [48] of Epoch[90] gave NaN loss and it will be ignored
# Batch [49] of Epoch[90] gave NaN loss and it will be ignored
# Batch [50] of Epoch[90] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 62.71it/s, epoch=91/100, avg_epoch_loss=nan]
#   0%|          | 0/50 [00:00<?, ?it/s]Batch [1] of Epoch[91] gave NaN loss and it will be ignored
# Batch [2] of Epoch[91] gave NaN loss and it will be ignored
# Batch [3] of Epoch[91] gave NaN loss and it will be ignored
# Batch [4] of Epoch[91] gave NaN loss and it will be ignored
# Batch [5] of Epoch[91] gave NaN loss and it will be ignored
# Batch [6] of Epoch[91] gave NaN loss and it will be ignored
# Batch [7] of Epoch[91] gave NaN loss and it will be ignored
# Batch [8] of Epoch[91] gave NaN loss and it will be ignored
# Batch [9] of Epoch[91] gave NaN loss and it will be ignored
# Batch [10] of Epoch[91] gave NaN loss and it will be ignored
# Batch [11] of Epoch[91] gave NaN loss and it will be ignored
# Batch [12] of Epoch[91] gave NaN loss and it will be ignored
# Batch [13] of Epoch[91] gave NaN loss and it will be ignored
# Batch [14] of Epoch[91] gave NaN loss and it will be ignored
# Batch [15] of Epoch[91] gave NaN loss and it will be ignored
# Batch [16] of Epoch[91] gave NaN loss and it will be ignored
# Batch [17] of Epoch[91] gave NaN loss and it will be ignored
# Batch [18] of Epoch[91] gave NaN loss and it will be ignored
# Batch [19] of Epoch[91] gave NaN loss and it will be ignored
# Batch [20] of Epoch[91] gave NaN loss and it will be ignored
# Batch [21] of Epoch[91] gave NaN loss and it will be ignored
# Batch [22] of Epoch[91] gave NaN loss and it will be ignored
# Batch [23] of Epoch[91] gave NaN loss and it will be ignored
# Batch [24] of Epoch[91] gave NaN loss and it will be ignored
# Batch [25] of Epoch[91] gave NaN loss and it will be ignored
# Batch [26] of Epoch[91] gave NaN loss and it will be ignored
# Batch [27] of Epoch[91] gave NaN loss and it will be ignored
# Batch [28] of Epoch[91] gave NaN loss and it will be ignored
# Batch [29] of Epoch[91] gave NaN loss and it will be ignored
# Batch [30] of Epoch[91] gave NaN loss and it will be ignored
# Batch [31] of Epoch[91] gave NaN loss and it will be ignored
# Batch [32] of Epoch[91] gave NaN loss and it will be ignored
# Batch [33] of Epoch[91] gave NaN loss and it will be ignored
# Batch [34] of Epoch[91] gave NaN loss and it will be ignored
# Batch [35] of Epoch[91] gave NaN loss and it will be ignored
# Batch [36] of Epoch[91] gave NaN loss and it will be ignored
# Batch [37] of Epoch[91] gave NaN loss and it will be ignored
# Batch [38] of Epoch[91] gave NaN loss and it will be ignored
# Batch [39] of Epoch[91] gave NaN loss and it will be ignored
# Batch [40] of Epoch[91] gave NaN loss and it will be ignored
# Batch [41] of Epoch[91] gave NaN loss and it will be ignored
# Batch [42] of Epoch[91] gave NaN loss and it will be ignored
# Batch [43] of Epoch[91] gave NaN loss and it will be ignored
# Batch [44] of Epoch[91] gave NaN loss and it will be ignored
# Batch [45] of Epoch[91] gave NaN loss and it will be ignored
# Batch [46] of Epoch[91] gave NaN loss and it will be ignored
# Batch [47] of Epoch[91] gave NaN loss and it will be ignored
# Batch [48] of Epoch[91] gave NaN loss and it will be ignored
# Batch [49] of Epoch[91] gave NaN loss and it will be ignored
# Batch [50] of Epoch[91] gave NaN loss and it will be ignored
# 100%|██████████| 50/50 [00:00<00:00, 62.07it/s, epoch=92/100, avg_epoch_loss=nan]
# Early stopping based on learning rate scheduler callback (min_lr was reached).

# %%
from gluonts.evaluation.backtest import make_evaluation_predictions

forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100
)

print("Obtaining time series conditioning values ...")
tss = list(tqdm(ts_it, total=len(test_ds)))
print("Obtaining time series predictions ...")
forecasts = list(tqdm(forecast_it, total=len(test_ds)))
# Out:
# Obtaining time series conditioning values ...
#   0%|          | 0/32 [00:00<?, ?it/s]
# Obtaining time series predictions ...
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
if submission == False:
    
    from gluonts.evaluation import Evaluator
    
    class M5Evaluator(Evaluator):
        
        def get_metrics_per_ts(self, time_series, forecast):
            successive_diff = np.diff(time_series.values.reshape(len(time_series)))
            successive_diff = successive_diff ** 2
            successive_diff = successive_diff[:-prediction_length]
            denom = np.mean(successive_diff)
            pred_values = forecast.samples.mean(axis=0)
            true_values = time_series.values.reshape(len(time_series))[-prediction_length:]
            num = np.mean((pred_values - true_values)**2)
            rmsse = num / denom
            metrics = super().get_metrics_per_ts(time_series, forecast)
            metrics["RMSSE"] = rmsse
            return metrics
        
        def get_aggregate_metrics(self, metric_per_ts):
            wrmsse = metric_per_ts["RMSSE"].mean()
            agg_metric , _ = super().get_aggregate_metrics(metric_per_ts)
            agg_metric["MRMSSE"] = wrmsse
            return agg_metric, metric_per_ts
        
    
    evaluator = M5Evaluator(quantiles=[0.5, 0.67, 0.95, 0.99])
    agg_metrics, item_metrics = evaluator(iter(tss), iter(forecasts), num_series=len(test_ds))
    print(json.dumps(agg_metrics, indent=4))
# Out:
# Running evaluation: 100%|██████████| 32/32 [00:00<00:00, 639.45it/s]
# {
#     "MSE": 54310.6763587296,
#     "abs_error": 31046.0,
#     "abs_target_sum": 299231.0,
#     "abs_target_mean": 1168.87109375,
#     "seasonal_error": 49.381076388888886,
#     "MASE": 2.3418811115136995,
#     "MAPE": 0.16673889401135966,
#     "sMAPE": 0.1878136929590255,
#     "MSIS": 33.79031718604968,
#     "QuantileLoss[0.5]": 31046.0,
#     "Coverage[0.5]": 0.390625,
#     "QuantileLoss[0.67]": 33061.82,
#     "Coverage[0.67]": 0.44921875,
#     "QuantileLoss[0.95]": 25748.300000000003,
#     "Coverage[0.95]": 0.6640625,
#     "QuantileLoss[0.99]": 20622.059999999998,
#     "Coverage[0.99]": 0.72265625,
#     "RMSE": 233.0465111490185,
#     "NRMSE": 0.19937742698500066,
#     "ND": 0.10375261921391835,
#     "wQuantileLoss[0.5]": 0.10375261921391835,
#     "wQuantileLoss[0.67]": 0.1104892875403952,
#     "wQuantileLoss[0.95]": 0.08604823698079411,
#     "wQuantileLoss[0.99]": 0.06891685687645999,
#     "mean_absolute_QuantileLoss": 27619.545,
#     "mean_wQuantileLoss": 0.09230175015289191,
#     "MAE_Coverage": 0.220859375,
#     "OWA": NaN,
#     "MRMSSE": 19.297494616359472
# }

# %%
def mase(n,seas,h,y,f):
    return np.mean(((n-seas)/h
            * (np.sum(np.abs(y[n:n+h,:] - f), axis=0)
               / np.sum(np.abs(y[seas:n, :] - y[:n-seas, :]), axis=0))))

# %%
def generate_groups_data_matrix(groups):

    for group in groups['train']['groups_idx'].keys():
        groups['train']['groups_idx'][group] = groups['train']['groups_idx'][group].reshape(groups['train']['s'], groups['train']['n']).T[0,:]
        groups['predict']['groups_idx'][group] = groups['predict']['groups_idx'][group].reshape(groups['predict']['s'], groups['predict']['n']).T[0,:]

    groups['train']['full_data'] = groups['train']['data'].reshape(groups['train']['s'], groups['train']['n']).T
    groups['train']['data'] = groups['train']['data'].reshape(groups['train']['s'], groups['train']['n']).T

    groups['train']['n_series_idx_full'] = groups['train']['n_series_idx'].reshape(groups['train']['s'], groups['train']['n']).T[0,:]
    groups['train']['n_series_idx'] = groups['train']['n_series_idx'].reshape(groups['train']['s'], groups['train']['n']).T[0,:]

    groups['predict']['n_series_idx'] = groups['predict']['n_series_idx'].reshape(groups['predict']['s'], groups['predict']['n']).T[0,:]

    return groups

# %%
def calculate_metrics(pred_samples,
                      groups):

    pred_s0 = pred_samples.shape[0]
    pred_s1 = pred_samples.shape[1]
    pred_s2 = pred_samples.shape[2]

    pred_samples = pred_samples.reshape(pred_s0, pred_s1*pred_s2, order='F')

    seasonality = groups['seasonality']
    h = groups['h']
    
    n = groups['predict']['n']
    s = groups['predict']['s']
    y_f = groups['predict']['data'].reshape(s, n).T
    y_all_g = {}
    f_all_g = {}
    
    mase_ = {}
    rmse_ = {}
    
    # Bottom
    y_all_g['bottom'] = y_f
    f_all_g['bottom'] = np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:]
    
    mase_['bottom'] = np.round(mase(n=n-h, 
                                     seas=seasonality, 
                                     h=h, 
                                     y=y_f, 
                                     f=np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:]),3)
    rmse_['bottom'] = np.round(mean_squared_error(y_f[n-h:n,:], np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:], squared=False), 3)

    # Total
    y_all_g['total'] = np.sum(y_f, axis=1).reshape(-1,1)
    f_all_g['total'] = np.sum(np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:], axis=1).reshape(-1,1)
    
    mase_['total'] = np.round(mase(n=n-h, 
                                     seas=seasonality, 
                                     h=h, 
                                     y=np.sum(y_f, axis=1).reshape(-1,1), 
                                     f=np.sum(np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:], axis=1).reshape(-1,1))
                            ,3)
    rmse_['total'] = np.round(mean_squared_error(np.sum(y_f, axis=1).reshape(-1,1)[n-h:n,:], 
                                             np.sum(np.mean(pred_samples, axis=0).reshape(s, n).T[n-h:n,:],axis=1).reshape(-1,1), 
                                             squared=False), 3)

    # Groups
    idx_dict_new = {}
    for group in list(groups['predict']['groups_names'].keys()):
        y_g = np.zeros((groups['predict']['n'], groups['predict']['groups_names'][group].shape[0]))
        f_g = np.zeros((h, groups['predict']['groups_names'][group].shape[0]))

        for idx, name in enumerate(groups['predict']['groups_names'][group]):               

            g_n = groups['predict']['groups_n'][group]

            idx_dict_new[name] = np.where(groups['predict']['groups_idx'][group]==idx,1,0)

            y_g[:,idx] = np.sum(idx_dict_new[name]*y_f, axis=1)
            f_g[:,idx] = np.sum(idx_dict_new[name]*np.mean(pred_samples, axis=0).reshape(s, n).T, axis=1)[n-h:n]

        y_all_g[group] = np.sum(y_g, axis=1).reshape(-1,1)
        f_all_g[group] = np.sum(f_g, axis=1).reshape(-1,1)

        mase_[group] = np.round(mase(n=n-h, 
                                     seas=seasonality, 
                                     h=h, 
                                     y=y_g, 
                                     f=f_g)
                                ,3)

        rmse_[group] = np.round(mean_squared_error(y_g[n-h:n,:], f_g, squared=False), 3)

    # All
    y_all = np.concatenate([y_all_g[x] for x in y_all_g], 1)
    f_all = np.concatenate([f_all_g[x] for x in f_all_g], 1)

    mase_['all'] = np.round(mase(n=n-h, 
                         seas=seasonality, 
                         h=h, 
                         y=y_all, 
                         f=f_all),3)
    rmse_['all'] = np.round(mean_squared_error(y_all[n-h:n,:], f_all, squared=False), 3)
    
    results = {}
    results['mase'] = mase_
    results['rmse'] = rmse_
    return results

# %%
groups_input = {
    'state': [0],
    'gender': [1],
    'legal': [2]
}

# %%
prison_pivot = prison_pivot.T

# %%
groups = generate_groups_data_flat(y = prison_pivot, 
                               groups_input = groups_input, 
                               seasonality=4, 
                               h=8)
groups = generate_groups_data_matrix(groups)
# Out:
# Number of groups: 3
# 	state: 8
# 	gender: 2
# 	legal: 2
# Total number of series: 32
# Number of points per series for train: 40
# Total number of points: 48
# Seasonality: 4
# Forecast horizon: 8

# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm

def visualize_fit(groups, pred_samples_fit, n_series_to_show):
    assert n_series_to_show%2 == 0, "'n_series_to_show' must be an integer even number"
    fig, ax = plt.subplots(int(n_series_to_show/2), 2, figsize=(12,n_series_to_show*2))
    n = groups['train']['n']
    ax = np.ravel(ax)
    for i in range(n_series_to_show):
        ax[i].plot(np.arange(n), pred_samples_fit[:,:,i].T, alpha=0.003, color='orange', label='model fit')
        ax[i].plot(np.arange(n), groups['train']['data'][:,i], label='data')

def visualize_predict(groups, pred_samples_predict, n_bottom_series_to_show, levels=[0,1,2]):
    """
    Parameters
    ----------
    levels: list
                0 -> total, 1 -> groups, 2 -> bottom
                Default to [0,1,2]
    """
    n_series_to_show = n_bottom_series_to_show
    if 0 in levels:
        n_series_to_show += 1 
    if 1 in levels:
        for _,k in groups['predict']['groups_n'].items():
            n_series_to_show += 2 # only show two series of each group aggregate
            
    fig, ax = plt.subplots(int(n_series_to_show/2), 2, figsize=(12,n_series_to_show*2))
    ax = np.ravel(ax)
    n = groups['train']['n']
    n_new = groups['predict']['n']
    j = 0
    # Total
    if 0 in levels:
        y_f = groups['predict']['data'].reshape(groups['predict']['s'], groups['predict']['n']).T
        y_all_g = np.sum(y_f, axis=1).reshape(-1,1)

        ax[j].fill_between(np.arange(n_new), 
                        np.percentile(np.sum(pred_samples_predict, axis=2).T, axis=1, q=2.5),
                        np.percentile(np.sum(pred_samples_predict, axis=2).T, axis=1, q=97.5),
                        label='95% CI', alpha=0.1)
        ax[j].plot(np.arange(n_new), 
                np.median(np.sum(pred_samples_predict, axis=2).T, axis=1),
                color='tab:blue', alpha=0.7, label='median')
        ax[j].plot(np.arange(n_new), 
                np.mean(np.sum(pred_samples_predict, axis=2).T, axis=1),
                color='b', label='mean')
        ax[j].set_ylim(0,max(np.sum(groups['predict']['data'].reshape(groups['predict']['s'], groups['predict']['n']).T, axis=1)*1.5))
        ax[j].plot(np.sum(groups['train']['full_data'], axis=1), 
                color='darkorange', label='training data')
        ax[j].plot(np.arange(n, n_new),
                np.sum(groups['predict']['data'].reshape(groups['predict']['s'], groups['predict']['n']).T, axis=1)[n:],
                color='r', label='forecasting data')
        ax[j].legend()
        ax[j].set_title('Total: sum of all series')
        j+=1
    if 1 in levels:
        idx_dict_new = {}
        y_all_g = {}
        f_all_g = {}
        y_f = groups['predict']['data'].reshape(groups['predict']['s'], groups['predict']['n']).T
        for id_group, group in enumerate(list(groups['predict']['groups_names'].keys())):
            y_g = np.zeros((groups['predict']['n'], 1))
            f_g = np.zeros((500, groups['predict']['groups_names'][group].shape[0]))
                
            y_all_g[group] = {}
            f_all_g[group] = {}
            
            for idx, name in enumerate(groups['predict']['groups_names'][group]):               
                # Only show 2 plots of each group -> change this is to show more
                if idx < 2:
                    g_n = groups['predict']['groups_n'][group]

                    idx_dict_new[name] = np.where(groups['predict']['groups_idx'][group]==idx,1,0)

                    y_g = np.sum(idx_dict_new[name].reshape(1,-1)*y_f, axis=1)
                    f_g = np.sum(idx_dict_new[name].reshape(1,-1)*pred_samples_predict, axis=(2))
                    
                    y_all_g[group][name] = y_g
                    f_all_g[group][name] = f_g
                    
                    ax[j].fill_between(np.arange(groups['predict']['n']), 
                                    np.percentile(f_all_g[group][name], axis=0, q=2.5),
                                    np.percentile(f_all_g[group][name], axis=0, q=97.5),
                                    label='95% CI', alpha=0.1)
                    ax[j].plot(np.arange(groups['predict']['n']), 
                            np.median(f_all_g[group][name], axis=0),
                            color='tab:blue', alpha=0.7, label='median')
                    ax[j].plot(np.arange(groups['predict']['n']), 
                            np.mean(f_all_g[group][name], axis=0),
                            color='b', label='mean')
                    ax[j].set_ylim(0,max(y_all_g[group][name])*1.5)
                    ax[j].plot(y_all_g[group][name][:groups['train']['n']], 
                            color='darkorange', label='training data')
                    ax[j].plot(np.arange(groups['train']['n'], groups['predict']['n']),
                            y_all_g[group][name][groups['train']['n']:],
                            color='r', label='forecasting data')
                    ax[j].legend()
                    ax[j].set_title(f'Group {group}: {name}')
                    
                    j+=1
    if 2 in levels:
        for i in range(n_bottom_series_to_show-1):
            ax[j].fill_between(np.arange(n_new), 
                            np.percentile(pred_samples_predict[:,:,i], axis=0, q=2.5),
                            np.percentile(pred_samples_predict[:,:,i], axis=0, q=97.5),
                            label='95% CI', alpha=0.1)
            ax[j].plot(np.arange(n_new), np.median(pred_samples_predict[:,:,i], axis=0), color='tab:blue', alpha=0.7, label='median')
            ax[j].plot(np.arange(n_new), np.mean(pred_samples_predict[:,:,i], axis=0), color='b', label='mean')
            ax[j].set_ylim(0,max(groups['predict']['data'][i*n_new:i*n_new+n_new])*1.5)
            ax[j].plot(groups['train']['full_data'][:,i], color='darkorange', label='training data')
            ax[j].plot(np.arange(n, n_new), groups['predict']['data'][i*n_new+n:i*n_new+n_new], color='r', label='forecasting data')
            ax[j].legend()
            ax[j].set_title(f'Series {i}',)
            j+=1

def traceplot(trace):
    return pm.traceplot(trace, var_names=['~f_'], filter_vars="like")

def model_graph(model):
    return pm.model_graph.model_to_graphviz(model)

def visualize_prior(groups, prior_checks, n_series_to_show):

    assert n_series_to_show%2 == 0, "'n_series_to_show' must be an integer even number"

    fig, ax = plt.subplots(int(n_series_to_show/2), 2, figsize=(12,n_series_to_show*2))
    ax = np.ravel(ax)

    for i in range(n_series_to_show):
        ax[i].plot(prior_checks['prior_like'][:,:,i].T, color='b', alpha=0.1)
        ax[i].plot(groups['train']['data'][:,i], color='darkorange')
        ax[i].set_ylim(min(min(groups['train']['data'][:,i])*5,0), max(groups['train']['data'][:,i])*5)

def plot_elbo(trace, last_it=80000):
    plt.plot(-trace.hist[-last_it:])
    plt.title(f'ELBO of the last {last_it} iterations')

def plot_gps_components(series, groups, trace):
    g_idx = [g_idx[series] for g_idx in list(groups['predict']['groups_idx'].values())]

    names_g  = [names[g_idx] for g_idx, names in zip(g_idx, list(groups['train']['groups_names'].values()))]

    _, ax = plt.subplots(groups['train']['g_number']+2, 1, figsize=(20, 20))

    ax = ax.ravel()

    color = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red',
            'tab:purple', 'tab:brown', 'tab:pink', 'tab:grey',
            'tab:olive']
    ax[0].set_title(f'Sum of all GPs for series {series}, represented by groups {names_g}')

    trace_vi = []
    for i in range(groups['train']['g_number']):
        trace_vi.append(trace[f'f_{names_g[i]}'].T)
    trace_vi = np.asarray(trace_vi)

    sum_gps = np.sum(trace_vi, axis=0)
    ax[0].plot(sum_gps, color='black', alpha=0.1)
    ax[0].set_ylim(min(0, np.min(sum_gps)*1.1), np.max(sum_gps)*1.1)

    ax[1].set_title('Stacked representation of the sum of the GPs')
    ax[1].stackplot(np.arange(trace_vi.shape[1]), np.mean(trace_vi, axis=2), colors=color)
    ax[1].set_ylim(min(0, np.min(sum_gps)*1.1), np.max(sum_gps)*1.1)

    for i in range(groups['train']['g_number']):
        ax[i+2].plot(trace_vi[i,:,:], color=color[i], alpha=0.1)
        group = list(groups['train']['groups_names'].keys())[i]
        ax[i+2].set_title(f'GP for {group} {names_g[i]}')
        ax[i+2].set_ylim(min(0, np.min(sum_gps)*1.1), np.max(sum_gps)*1.1)

# %%
res =np.zeros((len(forecasts), 100, 8))
for i, j in enumerate(forecasts):
    res[i] = j.samples

# %%
res = np.concatenate((np.zeros((32, 100, 40), dtype=np.float64), res), axis=2)

# %%
res = np.transpose(res, (1, 2, 0))

# %%
visualize_predict(groups, res, 10)

# %%
from sklearn.metrics import mean_squared_error

results = calculate_metrics(res, groups)
metrics_to_table(results)
# Out:
# <table>
# <tbody>
# <tr><td>    </td><td>bottom </td><td>total   </td><td>state  </td><td>gender </td><td>legal   </td><td>all    </td></tr>
# <tr><td>mase</td><td>2.333  </td><td>1.055   </td><td>1.784  </td><td>1.378  </td><td>2.602   </td><td>2.191  </td></tr>
# <tr><td>rmse</td><td>136.586</td><td>1270.181</td><td>337.968</td><td>637.898</td><td>1288.691</td><td>262.541</td></tr>
# </tbody>
# </table>

# %%
plot_log_path = "./plots/"
directory = os.path.dirname(plot_log_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
def plot_prob_forecasts(ts_entry, forecast_entry, path, sample_id, inline=True):
    plot_length = 150
    prediction_intervals = (50, 67, 95, 99)
    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]

    _, ax = plt.subplots(1, 1, figsize=(10, 7))
    ts_entry[-plot_length:].plot(ax=ax)
    forecast_entry.plot(prediction_intervals=prediction_intervals, color='g')
    ax.axvline(ts_entry.index[-prediction_length], color='r')
    plt.legend(legend, loc="upper left")
    if inline:
        plt.show()
        plt.clf()
    else:
        plt.savefig('{}forecast_{}.pdf'.format(path, sample_id))
        plt.close()

print("Plotting time series predictions ...")
for i in tqdm(range(5)):
    ts_entry = tss[i]
    forecast_entry = forecasts[i]
    plot_prob_forecasts(ts_entry, forecast_entry, plot_log_path, i)
# Out:
# Plotting time series predictions ...
#   0%|          | 0/5 [00:00<?, ?it/s]
